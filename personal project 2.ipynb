# %% [markdown]
# # data set of mercidies
# Data set contains information of price, transmission, mileage, fuel type,
# road tax, miles per gallon (mpg), and engine size
#
# data description:
#
# model: Mercedez model.
#
# year: registraion year.
#
# price: price in Euros.
#
# transmission: type of gear box.
#
# mileage: distance used.
#
# fuelType: engine fuel.
#
# tax: road tax.
#
# mpg: miles per galoon.
#
# engineSize: size in litres.
#
#
# It'd be cool to have some insights and vizualisations of the data. Also, am open to ideas on how
# to expand the data set.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("merc.csv")
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13119 non-null  object
#  1   year          13119 non-null  int64
#  2   price         13119 non-null  int64
#  3   transmission  13119 non-null  object
#  4   mileage       13119 non-null  int64
#  5   fuelType      13119 non-null  object
#  6   tax           13119 non-null  int64
#  7   mpg           13119 non-null  float64
#  8   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 922.6+ KB

# %%
df.transmission.value_counts().plot.pie(fontsize = 18, autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='transmission'>

# %% [raw]
# 1. 52% cars listed as semi autometic transmission.and 36% are of autometic transmission.
# 2.very few cars listed as manual transmission.

# %%
df["age"]= 2021- df["year"]
del df["year"]
df
# Out:
#             model  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  73948    Automatic     4000   Petrol  325  30.1
# ...           ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize  age
# 0             1.8   16
# 1             2.1    4
# 2             5.5    5
# 3             4.0    5
# 4             4.0    5
# ...

# %%
df3=sns.relplot(x="age",y="mileage",col="fuelType",hue="transmission",height=3,aspect=1,data=df)
df3

# %% [raw]
# 3. most cars have been used upto 150000 kilometers .
#
# 4. all hybrid cars having only autumetic and semi autometic transmission.

# %%
df1=sns.scatterplot(x="mpg",y="price",data=df)

# %% [raw]
# 5. most of cars listed as engine efficiancy as 25 to 75 miles per gallon.
#
# 6. almost high price cars having engine efficiancy 25 to 30 miles per gallon.

# %%
df2=sns.barplot(x="model",y="price",data=df)

# %% [raw]
# 7.A class G class and SL class cars are the most explensive.
#
# 8.A class and C class cars having high count in range 15000 to 35000.

# %%
df["model"].value_counts().sort_values(ascending=False)
# Out:
#  C Class      3747
#  A Class      2561
#  E Class      1953
#  GLC Class     960
#  GLA Class     847
#  B Class       591
#  CL Class      511
#  GLE Class     461
#  SL CLASS      260
#  CLS Class     237
#  V Class       207
#  S Class       197
#  GL Class      121
#  SLK            95
#  CLA Class      86
#  X-CLASS        82
#  M Class        79
#  GLS Class      74
#  GLB Class      19
#  G Class        15
#  CLK             7
#  CLC Class       3
#  R Class         2
# 180              1
# 230              1
# 220              1
# 200              1
# Name: model, dtype: int64

# %% [raw]
# 9. most of cars listed from C class, A class, and E class
#
# 10. very few cars are listed from 180,230,220,200 classes.

# %%
sns.heatmap(df.corr(), annot=True, cmap="RdBu")
plt.show()

# %% [raw]
# 11.medium positive correlation seen between age and mielage.
#
# 12.almost low negative correlation seen between mielage and price, age and price, mpg and price, mpg and tax.

# %%
sns.pairplot(df)

# %%
df=sns.relplot(x="age",y="price",hue="engineSize",col="fuelType",style="transmission",col_wrap=2,height=6,aspect=1,data=df)

# %% [raw]
# """
# 13. there is most of cars having fuel type petrol and diesel and almost expensive cars having
#     fuel type petrol with semi auto transmission which are almost upto 7 year old excepting one .
#
# 14. most of cars having auto transmission.
#
# 15. some petrol cars having engine size more then 5.
#
# 16.  most big engines listed for autometic petrol cars and some for also semi-autometic petrol cars.
# """
